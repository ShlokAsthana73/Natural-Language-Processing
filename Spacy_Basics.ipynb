# %% [markdown]
# <a href="https://colab.research.google.com/github/ShlokAsthana73/NLP/blob/main/Spacy_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import spacy

# %%
nlp = spacy.load('en_core_web_sm')

#create doc object
doc = nlp(u'tesla is looking at buying U.S. startup for $6 million')

#print each token seprately
for token in doc:
    print(token.text,token.pos_ ,token.dep_)
# Out:
# tesla PROPN nsubj
# is AUX aux
# looking VERB ROOT
# at ADP prep
# buying VERB pcomp
# U.S. PROPN dobj
# startup VERB advcl
# for ADP prep
# $ SYM quantmod
# 6 NUM compound
# million NUM pobj

# %%
doc2 = nlp(u"Tesla isn't     looking into startups anymore.")
for token in doc2:
    print(token.text,token.pos_ ,token.dep_)
# Out:
# Tesla PROPN nsubj
# is AUX aux
# n't PART neg
#      SPACE dep
# looking VERB ROOT
# into ADP prep
# startups NOUN pobj
# anymore ADV advmod
# . PUNCT punct

# %%
doc2[4]
# Out:
# looking

# %%
type(doc2)
# Out:
# spacy.tokens.doc.Doc

# %%
doc[0].pos_
# Out:
# 'PROPN'

# %%
doc[0].dep_
# Out:
# 'nsubj'

# %%
spacy.explain('PROPN')
# Out:
# 'proper noun'

# %%
spacy.explain(doc[0].dep_)
# Out:
# 'nominal subject'

# %%
doc2[4].text
# Out:
# 'looking'

# %%
doc2[4].lemma_
# Out:
# 'look'

# %%
doc2[4].pos_
# Out:
# 'VERB'

# %%
doc2[4].tag_
# Out:
# 'VBG'

# %%
spacy.explain(doc2[4].tag_)
# Out:
# 'verb, gerund or present participle'

# %%
doc2[4].shape_
# Out:
# 'xxxx'

# %%
doc2[4].is_alpha
# Out:
# True

# %%
doc2[4].is_stop
# Out:
# False

# %%
print(doc2[4].pos_)
print(doc2[4].tag_ +"/"+spacy.explain(doc2[4].tag_))
# Out:
# VERB
# VBG/verb, gerund or present participle

# %%
print(doc2[0].text +"  _:  "+ doc2[0].shape_)
print(doc[5].text +"  _:  "+ doc2[5].shape_)
# Out:
# Tesla  _:  Xxxxx
# U.S.  _:  xxxx

# %%
#print(doc[4].text + " : " + doc[4].is_stop)

# %%
doc3 =nlp(u'although commonly attributed to john lennon from his song "beautiful boy", \
the phrase "Life is what happens to us while we are making other plans " was written by \
 cartoonist Allen Saunders and published in Reader \'s Digest in 1957 , when Lennon was 17.')

# %%
life_quote = doc3[16:30]
print(life_quote)
# Out:
# "Life is what happens to us while we are making other plans "

# %%
type(life_quote)
# Out:
# spacy.tokens.span.Span

# %%
doc4 = nlp(u'this is the first sentence. this is another sentence. this is the last sentence')

# %%
for sent in doc4.sents:
    print(sent)
# Out:
# this is the first sentence.
# this is another sentence.
# this is the last sentence

# %%
print(f"'{doc4[6]}'word  --  {doc4[4].is_sent_start}")
# Out:
# 'this'word  --  False

# %%
doc4[6].is_stop
# Out:
# True
