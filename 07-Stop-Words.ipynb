# %%
import nbformat

def get_notebook_content(notebook_path):
    with open(notebook_path, 'r', encoding='utf-8') as f:
        nb = nbformat.read(f, as_version=4)
    
    content = []
    for cell in nb.cells:
        if cell.cell_type == 'code':
            content.append(cell.source)
        elif cell.cell_type == 'markdown':
            content.append(f"'''{cell.source}'''")
    
    return '\n\n'.join(content)

notebook_path = r"C:\Users\Sahil\Nlp suneet\07-Stop-Words.ipynb"  # replace with your notebook path
print(get_notebook_content(notebook_path))
# Out:
# import spacy
# nlp = spacy.load("en_core_web_sm")
#
# print(nlp.Defaults.stop_words )
#
# len(nlp.Defaults.stop_words)
#
# nlp.vocab['myself'].is_stop
#
# nlp.vocab['mystery'].is_stop
#
# '''add to stop word
# '''
#
# '''when every add stop word is lower case'''
#
# nlp.Defaults.stop_words.add('btw')
#
# nlp.vocab['btw'].is_stop = True
#
# nlp.vocab['btw'].is_stop
#
# len(nlp.Defaults.stop_words)
#
# '''to remove the stop word'''
#
# nlp.vocab['beyond'].is_stop
#
# nlp.Defaults.stop_words.remove('beyond')
# nlp.vocab['beyond'].is_stop = False
#
# nlp.vocab['beyond'].is_stop
#
# len(nlp.Defaults.stop_words)

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

# %%
print(nlp.Defaults.stop_words )
# Out:
# {'us', 'move', 'his', 'what', 'own', 'always', 'herself', 'seem', 'out', 'could', 'meanwhile', 'part', 'seemed', 'front', 'often', 'a', 'someone', 'via', 'if', 'six', 'together', 'towards', 'two', 'show', 'besides', 'your', 'five', 'her', 'in', '’re', 'between', 'make', 'nevertheless', 'mine', 'latterly', 'almost', 'him', 'other', 'per', 'fifty', '’s', "'ve", 'yourself', 'more', 'something', 'serious', 'anything', 'forty', 'amount', 'anyhow', 'take', 'either', 'beforehand', 'then', "'s", 'there', 'been', 'perhaps', 'get', 'three', 'go', 'never', 're', "n't", 'were', 'empty', 'nine', 'most', 'bottom', 'these', 'see', 'than', '’ve', 'onto', 'all', '’d', 'which', 'by', 'on', 'thereafter', 'who', 'everywhere', 'few', 'has', 'eight', 'against', 'became', 'whereby', 'with', 'yourselves', 'cannot', 'after', 'again', 'along', 'too', '‘d', 'seems', 'during', 'done', 'somewhere', 'just', 'once', 'twelve', 'anyway', 'themselves', 'himself', '‘ll', 'sometimes', 'without', 'please', 'indeed', 'fr
# ...

# %%
len(nlp.Defaults.stop_words)
# Out:
# 326

# %%
nlp.vocab['myself'].is_stop
# Out:
# True

# %%
nlp.vocab['mystery'].is_stop
# Out:
# False

# %% [markdown]
# add to stop word

# %% [markdown]
# when every add stop word is lower case

# %%
nlp.Defaults.stop_words.add('btw')

nlp.vocab['btw'].is_stop = True

# %%
nlp.vocab['btw'].is_stop
# Out:
# True

# %%
len(nlp.Defaults.stop_words)
# Out:
# 327

# %% [markdown]
# to remove the stop word

# %%
nlp.vocab['beyond'].is_stop
# Out:
# False

# %%
nlp.Defaults.stop_words.remove('beyond')
nlp.vocab['beyond'].is_stop = False

# %%
nlp.vocab['beyond'].is_stop
# Out:
# False

# %%
len(nlp.Defaults.stop_words)
# Out:
# 326
